# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('/content/UCI_Credit_Card.csv')

# %%
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE   AGE  PAY_0  PAY_2  PAY_3  \
# 0          1    20000.0    2          2         1  24.0      2      2     -1
# 1          2   120000.0    2          2         2  26.0     -1      2      0
# 2          3    90000.0    2          2         2   NaN      0      0      0
# 3          4    50000.0    2          2         1   NaN      0      0      0
# 4          5    50000.0    1          2         1  57.0     -1      0     -1
# ...      ...        ...  ...        ...       ...   ...    ...    ...    ...
# 29995  29996   220000.0    1          3         1  39.0      0      0      0
# 29996  29997   150000.0    1          3         2  43.0     -1     -1     -1
# 29997  29998    30000.0    1          2         2  37.0      4      3      2
# 29998  29999    80000.0    1          3         1  41.0      1     -1      0
# 29999  30000    50000.0    1          2         1  46.0      0      0      0
#
# ...

# %%
df.shape
# Out:
# (30000, 25)

# %%
df['default.payment.next.month'].value_counts()
# Out:
# 0    23364
# 1     6636
# Name: default.payment.next.month, dtype: int64

# %%
seaborn.countplot(df['default.payment.next.month'])
# Out:
# <Axes: ylabel='count'>

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           2
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default.payment.next.month    0
# dtype: int64

# %% [markdown]
# So, there are two null values in age column.

# %%
#To handling the null values:
missing=df.AGE.mean()

# %%
df.AGE=df.AGE.fillna(missing)

# %%
df.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default.payment.next.month    0
# dtype: int64

# %%
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE        AGE  PAY_0  PAY_2  \
# 0          1    20000.0    2          2         1  24.000000      2      2
# 1          2   120000.0    2          2         2  26.000000     -1      2
# 2          3    90000.0    2          2         2  35.485499      0      0
# 3          4    50000.0    2          2         1  35.485499      0      0
# 4          5    50000.0    1          2         1  57.000000     -1      0
# ...      ...        ...  ...        ...       ...        ...    ...    ...
# 29995  29996   220000.0    1          3         1  39.000000      0      0
# 29996  29997   150000.0    1          3         2  43.000000     -1     -1
# 29997  29998    30000.0    1          2         2  37.000000      4      3
# 29998  29999    80000.0    1          3         1  41.000000      1     -1
# 29999  30000    50000.0    1          2         1  46.000000      0      0
#
# ...

# %%
seaborn.countplot(x='AGE', hue='default.payment.next.month', data=df, palette='colorblind', edgecolor=seaborn.color_palette('dark',n_colors=1))
# Out:
# <Axes: xlabel='AGE', ylabel='count'>

# %%
seaborn.countplot(x='EDUCATION', hue='default.payment.next.month', data=df, palette='colorblind', edgecolor=seaborn.color_palette('dark',n_colors=1))
# Out:
# <Axes: xlabel='EDUCATION', ylabel='count'>

# %%
seaborn.countplot(x='MARRIAGE', hue='default.payment.next.month', data=df, palette='colorblind', edgecolor=seaborn.color_palette('dark',n_colors=1))
# Out:
# <Axes: xlabel='MARRIAGE', ylabel='count'>

# %%
df.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485499     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
x=df.drop(['ID','default.payment.next.month'], axis=1)
x
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE        AGE  PAY_0  PAY_2  PAY_3  \
# 0        20000.0    2          2         1  24.000000      2      2     -1
# 1       120000.0    2          2         2  26.000000     -1      2      0
# 2        90000.0    2          2         2  35.485499      0      0      0
# 3        50000.0    2          2         1  35.485499      0      0      0
# 4        50000.0    1          2         1  57.000000     -1      0     -1
# ...          ...  ...        ...       ...        ...    ...    ...    ...
# 29995   220000.0    1          3         1  39.000000      0      0      0
# 29996   150000.0    1          3         2  43.000000     -1     -1     -1
# 29997    30000.0    1          2         2  37.000000      4      3      2
# 29998    80000.0    1          3         1  41.000000      1     -1      0
# 29999    50000.0    1          2         1  46.000000      0      0      0
#
# ...

# %%
y=df['default.payment.next.month']
y
# Out:
# 0        1
# 1        1
# 2        0
# 3        0
# 4        0
#         ..
# 29995    0
# 29996    0
# 29997    1
# 29998    1
# 29999    1
# Name: default.payment.next.month, Length: 30000, dtype: int64

# %%
df.corr()
# Out:
#                                   ID  LIMIT_BAL       SEX  EDUCATION  \
# ID                          1.000000   0.026179  0.018497   0.039177
# LIMIT_BAL                   0.026179   1.000000  0.024755  -0.219161
# SEX                         0.018497   0.024755  1.000000   0.014232
# EDUCATION                   0.039177  -0.219161  0.014232   1.000000
# MARRIAGE                   -0.029079  -0.108139 -0.031389  -0.143464
# AGE                         0.018678   0.144715 -0.090874   0.175061
# PAY_0                      -0.030575  -0.271214 -0.057643   0.105364
# PAY_2                      -0.011215  -0.296382 -0.070771   0.121566
# PAY_3                      -0.018494  -0.286123 -0.066096   0.114025
# PAY_4                      -0.002735  -0.267460 -0.060173   0.108793
# PAY_5                      -0.022199  -0.249411 -0.055064   0.097520
# PAY_6                      -0.020270  -0.235195 -0.044008   0.082316
# BILL_AMT1                   0.019389   0.285430 -0.033642   0.023581
# ...

# %% [markdown]
# # SUPPORT VACTOR MACHINE APPLICATION

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

# %%
xtrain, xtest, ytrain, ytest= train_test_split(x, y, test_size=.25, random_state=1)

# %%
xtrain
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE   AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 26340   150000.0    2          1         2  26.0      0      0      2      0
# 3877     50000.0    2          2         2  23.0      0      0      0      0
# 27081    80000.0    1          2         2  31.0      0      0      0      0
# 5440    120000.0    2          2         2  39.0      0      0      2      0
# 22164   150000.0    2          1         3  30.0      1     -1      2     -1
# ...          ...  ...        ...       ...   ...    ...    ...    ...    ...
# 17289   170000.0    2          3         1  40.0      1      2      0      0
# 5192    330000.0    2          1         1  41.0     -1     -1     -2     -2
# 12172    50000.0    1          2         2  22.0      0      0      0      0
# 235      80000.0    1          1         2  35.0     -1     -1     -1     -1
# 29733   300000.0    1          2         1  37.0     -2     -2     -1     -1
#
# ...

# %%
model = SVC(gamma='auto')

# %%
model.fit(xtrain,ytrain)
# Out:
# SVC(gamma='auto')

# %%
model.score(xtest, ytest)
# Out:
# 0.7792

# %% [markdown]
# RANDOM FOREST(RF)

# %%
#Applying Random Forest
from sklearn.ensemble import RandomForestClassifier

# %%
Rclf=RandomForestClassifier()

# %%
Rclf.fit(xtrain, ytrain)
# Out:
# RandomForestClassifier()

# %%
Rclf.score(xtest, ytest)
# Out:
# 0.8125333333333333

# %% [markdown]
# DECISION TREE(DT)

# %%
#Applying Decision Tree:
from sklearn.tree import DecisionTreeClassifier

# %%
Clf=DecisionTreeClassifier()

# %%
Clf.fit(xtrain, ytrain)
# Out:
# DecisionTreeClassifier()

# %%
Clf.score(xtest, ytest)
# Out:
# 0.7172
